# %%
import pandas as pd

# %%
df_users = pd.read_xml(r"D:/mada/programming/Datasets/Stack over flaw/Users.xml", parser="etree")

# %%
df_users.head()
# Out:
#    Id  Reputation             CreationDate   DisplayName  \
# 0  -1           1  2010-07-19T06:55:26.860     Community
# 1   2         101  2010-07-19T14:01:36.697  Geoff Dalgas
# 2   3         101  2010-07-19T15:34:50.507  Jarrod Dixon
# 3   4         101  2010-07-19T19:03:27.400        Emmett
# 4   5       12151  2010-07-19T19:03:57.227         Shane
#
#             LastAccessDate                      WebsiteUrl  \
# 0  2010-07-19T06:55:26.860  http://meta.stackexchange.com/
# 1  2019-02-07T22:01:05.890        http://stackoverflow.com
# 2  2019-02-07T16:22:42.717          http://jarroddixon.com
# 3  2016-11-24T19:37:25.313    http://minesweeperonline.com
# 4  2022-12-07T19:30:33.150         http://www.statalgo.com
#
#                 Location                                            AboutMe  \
# 0     on the server farm  <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...
# 1          Corvallis, OR  <p>Dev #2 who helped create Stack Overflow cur...
# ...

# %%
df_users['AboutMe'].head()
# Out:
# 0    <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...
# 1    <p>Dev #2 who helped create Stack Overflow cur...
# 2    <p>Former <a href="http://blog.stackoverflow.c...
# 3    <p>co-founder of <a href="https://airtable.com...
# 4    <p>Quantitative researcher focusing on statist...
# Name: AboutMe, dtype: object

# %%
pd.set_option('display.max_colwidth', None)
print(df_users['AboutMe'].head())  # Now full text will be shown
# Out:
# 0                                                                                                                                                                                                                             <p>Hi, I'm not really a person.</p>\n\n<p>I'm a background process that helps keep this site clean!</p>\n\n<p>I do things like</p>\n\n<ul>\n<li>Randomly poke old unanswered questions every hour so they get some attention</li>\n<li>Own community questions and answers so nobody gets unnecessary reputation from them</li>\n<li>Own downvotes on spam/evil posts that get permanently deleted</li>\n<li>Own suggested edits from anonymous users</li>\n<li><a href="http://meta.stackexchange.com/a/92006">Remove abandoned questions</a></li>\n</ul>\n
# ...

# %%
df_posts = pd.read_xml(r"D:/mada/programming/Datasets/Stack over flaw/Posts.xml", parser="etree")

# %%
df_posts.head()
# Out:
#    Id  PostTypeId  AcceptedAnswerId             CreationDate  Score  \
# 0   1           1              15.0  2010-07-19T19:12:12.510     52
# 1   2           1              59.0  2010-07-19T19:12:57.157     34
# 2   3           1               5.0  2010-07-19T19:13:28.577     71
# 3   4           1             135.0  2010-07-19T19:13:31.617     23
# 4   5           2               NaN  2010-07-19T19:14:43.050     90
#
#    ViewCount  \
# 0     5571.0
# 1    33737.0
# 2     6662.0
# 3    46243.0
# 4        NaN
#
# ...

# %%
pd.set_option('display.max_columns', None)  # Show all columns

# %%
df_posts.head()
# Out:
#    Id  PostTypeId  AcceptedAnswerId             CreationDate  Score  \
# 0   1           1              15.0  2010-07-19T19:12:12.510     52
# 1   2           1              59.0  2010-07-19T19:12:57.157     34
# 2   3           1               5.0  2010-07-19T19:13:28.577     71
# 3   4           1             135.0  2010-07-19T19:13:31.617     23
# 4   5           2               NaN  2010-07-19T19:14:43.050     90
#
#    ViewCount  \
# 0     5571.0
# 1    33737.0
# 2     6662.0
# 3    46243.0
# 4        NaN
#
# ...

# %%
df_posts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 415913 entries, 0 to 415912
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Id                     415913 non-null  int64
#  1   PostTypeId             415913 non-null  int64
#  2   AcceptedAnswerId       69774 non-null   float64
#  3   CreationDate           415913 non-null  object
#  4   Score                  415913 non-null  int64
#  5   ViewCount              209721 non-null  float64
#  6   Body                   415377 non-null  object
#  7   OwnerUserId            409899 non-null  float64
#  8   LastActivityDate       415913 non-null  object
#  9   Title                  209721 non-null  object
#  10  Tags                   209721 non-null  object
#  11  AnswerCount            209721 non-null  float64
#  12  CommentCount           415913 non-null  int64
#  13  ContentLicense         415913 non-null  object
# ...

# %%
df_posts.describe(
)
# Out:
#                   Id     PostTypeId  AcceptedAnswerId          Score  \
# count  415913.000000  415913.000000      69774.000000  415913.000000
# mean   308948.271552       1.513569     297890.517643       3.274168
# std    186281.711903       0.560686     183926.995968      10.070221
# min         1.000000       1.000000          5.000000     -59.000000
# 25%    143923.000000       1.000000     134099.000000       1.000000
# 50%    308791.000000       1.000000     296590.000000       1.000000
# 75%    470423.000000       2.000000     458013.250000       3.000000
# max    625559.000000       7.000000     625491.000000    1887.000000
#
#           ViewCount    OwnerUserId    AnswerCount   CommentCount  \
# count  2.097210e+05  409899.000000  209721.000000  415913.000000
# mean   2.166556e+03  116367.174982       0.969116       1.910488
# std    1.232523e+04  110163.962786       1.143410       2.716385
# min    2.000000e+00      -1.000000       0.000000       0.000000
# ...

# %%
df_posts['PostTypeId'].unique()
# Out:
# array([1, 2, 7, 5, 4, 6, 3], dtype=int64)

# %%
df_comments = pd.read_xml(r"D:/mada/programming/Datasets/Stack over flaw/Comments.xml", parser="etree")

# %%
df_comments.head()
# Out:
#    Id  PostId  Score  \
# 0   1       3      7
# 1   2       5      0
# 2   3       9      1
# 3   4       5     11
# 4   6      14     10
#
#                                                                                                                             Text  \
# 0                            Could be a poster child for argumentative and subjective.  At the least, need to define 'valuable'.
# 1                                                                                      Yes, R is nice- but WHY is it 'valuable'.
# 2                                                        Again- why?  How would I convince my boss to use this over, say, Excel.
# 3  It's mature, well supported, and a standard within certain scientific communities (popular in our AI department, for example)
# 4                                     why ask the question here?  All are community-wiki, why not just fix the canonical answer?
#
# ...

# %%
df_Tags = pd.read_xml(r"D:/mada/programming/Datasets/Stack over flaw/Tags.xml", parser="etree")

# %%
df_Tags
# Out:
#         Id                   TagName  Count  ExcerptPostId  WikiPostId
# 0        1                  bayesian   7844        20258.0     20257.0
# 1        2                     prior    978        62158.0     62157.0
# 2        3               elicitation     12            NaN         NaN
# 3        5               open-source     18            NaN         NaN
# 4        6             distributions   9359         8046.0      8045.0
# ...    ...                       ...    ...            ...         ...
# 1592  4821           detection-limit      1            NaN         NaN
# 1593  4822  boosted-regression-trees      1            NaN         NaN
# 1594  4823         decision-boundary      6            NaN         NaN
# 1595  4824             decision-rule      1            NaN         NaN
# 1596  4825                     omics      1       623462.0    623461.0
#
# [1597 rows x 5 columns]

# %%
df_Tags['TagName'].unique()
# Out:
# array(['bayesian', 'prior', 'elicitation', ..., 'decision-boundary',
#        'decision-rule', 'omics'], dtype=object)

# %%
df_Votes = pd.read_xml(r"D:/mada/programming/Datasets/Stack over flaw/Votes.xml", parser="etree")

# %%
df_Votes.head()
# Out:
#    Id  PostId  VoteTypeId             CreationDate  UserId  BountyAmount
# 0   1       3           2  2010-07-19T00:00:00.000     NaN           NaN
# 1   2       2           2  2010-07-19T00:00:00.000     NaN           NaN
# 2   3       5           2  2010-07-19T00:00:00.000     NaN           NaN
# 3   4       5           2  2010-07-19T00:00:00.000     NaN           NaN
# 4   5       3           2  2010-07-19T00:00:00.000     NaN           NaN

# %%
df_Votes['VoteTypeId'].value_counts()
# Out:
# VoteTypeId
# 2     1406639
# 1       70176
# 3       66195
# 10      55890
# 16      32841
# 15      21333
# 8        6703
# 9        6699
# 6        3919
# 11       2932
# 12        379
# 4          57
# 5          54
# 7          19
# Name: count, dtype: int64

# %%
df_PostHistory = pd.read_xml(r"D:/mada/programming/Datasets/Stack over flaw/PostHistory.xml", parser="etree")

# %%
df_PostHistory.head()
# Out:
#    Id  PostHistoryTypeId  PostId                          RevisionGUID  \
# 0   1                  2       1  e58bf7fd-e60f-4c58-a6e4-dfc91cf98a69
# 1   2                  1       1  e58bf7fd-e60f-4c58-a6e4-dfc91cf98a69
# 2   3                  3       1  e58bf7fd-e60f-4c58-a6e4-dfc91cf98a69
# 3   4                  2       2  18bf9150-f1cb-432d-b7b7-26d2f8e33581
# 4   5                  1       2  18bf9150-f1cb-432d-b7b7-26d2f8e33581
#
#               CreationDate  UserId  \
# 0  2010-07-19T19:12:12.510     8.0
# 1  2010-07-19T19:12:12.510     8.0
# 2  2010-07-19T19:12:12.510     8.0
# 3  2010-07-19T19:12:57.157    24.0
# 4  2010-07-19T19:12:57.157    24.0
#
#                                                                                                                                          Text  \
# 0                                                         How should I elicit prior distributions from experts when fitting a Bayesian model?
# ...

# %%
df_PostLinks = pd.read_xml(r"D:/mada/programming/Datasets/Stack over flaw/PostLinks.xml", parser="etree")

# %%
df_PostLinks.head()
# Out:
#     Id             CreationDate  PostId  RelatedPostId  LinkTypeId
# 0  108  2010-07-21T14:47:33.983     395            173           1
# 1  145  2010-07-23T16:30:41.780     548            539           1
# 2  151  2010-07-24T09:11:01.413     536            590           1
# 3  217  2010-07-26T20:12:15.600     375             30           1
# 4  263  2010-07-27T16:00:22.133     769             31           1

# %%
df_Badges = pd.read_xml(r"D:/mada/programming/Datasets/Stack over flaw/Badges.xml", parser="etree")

# %%
df_Badges.head()
# Out:
#    Id  UserId     Name                     Date  Class  TagBased
# 0   1       5  Teacher  2010-07-19T19:39:07.047      3     False
# 1   2       6  Teacher  2010-07-19T19:39:07.220      3     False
# 2   3       8  Teacher  2010-07-19T19:39:07.330      3     False
# 3   4      23  Teacher  2010-07-19T19:39:07.437      3     False
# 4   5      36  Teacher  2010-07-19T19:39:07.593      3     False

# %%
df_Badges['Name'].unique()
# Out:
# array(['Teacher', 'Student', 'Editor', 'Organizer', 'Supporter', 'Critic',
#        'Autobiographer', 'Nice Answer', 'Scholar', 'Commentator',
#        'Self-Learner', 'Mortarboard', 'Nice Question', 'Good Answer',
#        'Cleanup', 'Promoter', 'Disciplined', 'Citizen Patrol',
#        'Peer Pressure', 'Beta', 'Popular Question', 'Guru', 'Tumbleweed',
#        'Enthusiast', 'Good Question', 'Taxonomist', 'Benefactor',
#        'Enlightened', 'Civic Duty', 'Tag Editor', 'Announcer', 'Investor',
#        'Altruist', 'Necromancer', 'Suffrage', 'Sportsmanship', 'Fanatic',
#        'Electorate', 'Strunk & White', 'Revival', 'r', 'Talkative',
#        'Notable Question', 'Precognitive', 'Convention', 'Quorum',
#        'distributions', 'Favorite Question', 'time-series', 'regression',
#        'data-visualization', 'Pundit', 'probability', 'Vox Populi',
#        'hypothesis-testing', 'anova', 'clustering', 'Synonymizer',
#        'Yearling', 'Copy Editor', 'Excavator', 'Analytical',
# ...

# %%
x = len(df_Badges[df_Badges['TagBased']==True].loc[:,'Name'].unique())

# %%
x
# Out:
# 300
